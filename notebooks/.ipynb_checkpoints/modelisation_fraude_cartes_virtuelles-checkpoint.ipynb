# %%
# Étape 1 : Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# Étape 2 : Chargement des données

# Charger ton fichier de features
features_df = pd.read_csv("../features/features_cartes_virtuelles.csv") 
print("features charge")
# Out:
# features charge

# %%
# Étape 3 : Normalisation des features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(features_df)

print("normalisation reussi")
# Out:
# normalisation reussi

# %%
# Étape 4 : Définir la grille d’hyperparamètres à tester
contamination_vals = [0.01, 0.03, 0.05, 0.07, 0.1]
n_estimators_vals = [50, 100, 200]

# Étape 5 : Boucle d’optimisation
results = []

for contamination in contamination_vals:
    for n_estimators in n_estimators_vals:
        model = IsolationForest(contamination=contamination,
                                n_estimators=n_estimators,
                                random_state=42)
        model.fit(X_scaled)
        y_pred = model.predict(X_scaled)
        is_fraud = [1 if x == -1 else 0 for x in y_pred]
        nb_fraudes = sum(is_fraud)

        results.append({
            'contamination': contamination,
            'n_estimators': n_estimators,
            'nb_fraudes': nb_fraudes
        })

# Étape 6 : Résultats sous forme de DataFrame
results_df = pd.DataFrame(results)
print(results_df.head())
# Out:
#    contamination  n_estimators  nb_fraudes
# 0           0.01            50          27
# 1           0.01           100          27
# 2           0.01           200          27
# 3           0.03            50          81
# 4           0.03           100          81

# %%
# Étape 7 : Visualisation de l’impact des paramètres
plt.figure(figsize=(10, 6))
sns.lineplot(data=results_df, x='contamination', y='nb_fraudes', hue='n_estimators', marker='o')
plt.title("Optimisation des hyperparamètres - Isolation Forest")
plt.xlabel("Contamination (proportion anomalies)")
plt.ylabel("Nombre de fraudes détectées")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Étape 8 : Sélection de la meilleure combinaison
best_row = results_df.sort_values(by='nb_fraudes', ascending=False).iloc[0]
best_contamination = best_row['contamination']
best_n_estimators = best_row['n_estimators']


print(f"Meilleur modèle : contamination={best_contamination}, n_estimators={best_n_estimators}")
# Out:
# Meilleur modèle : contamination=0.1, n_estimators=50.0

# %%
# Réentraîner le meilleur modèle
best_model = IsolationForest(
    contamination=best_contamination,
    n_estimators=int(best_n_estimators),
    random_state=42
)
best_model.fit(X_scaled)

# Ajouter les prédictions au DataFrame original
features_df['is_fraud'] = [1 if x == -1 else 0 for x in best_model.predict(X_scaled)]

# Sauvegarde
features_df.to_csv("../features/features_cartes_virtuelles_optimise_avec_fraude.csv", index=False)
print("Fichier enrichi avec is_fraud exporté.")
# Out:
# Fichier enrichi avec is_fraud exporté.

# %%
# Nombre total de fraudes détectées
nb_fraude = features_df[features_df['is_fraud'] == 1].shape[0]
print(f"Nombre total d'utilisateurs suspects de fraude : {nb_fraude}")

# 1. Charger les données enrichies avec is_fraud
df_fraude = pd.read_csv("../features/features_cartes_virtuelles_optimise_avec_fraude.csv")

# 2. Charger les utilisateurs bruts (avec leurs vrais noms)
user_df = pd.read_csv("../datasets/user.csv")

# 3. Re-normaliser les id bruts pour retrouver la correspondance avec les user_id normalisés
scaler = MinMaxScaler()
user_df['user_id_normalise'] = scaler.fit_transform(user_df[['id']])

# 4. Fusion entre les prédictions de fraude et les noms d’utilisateur
df_rapport = df_fraude.merge(user_df[['id', 'username', 'user_id_normalise']], left_on='user_id', right_on='user_id_normalise', how='left')

# 5. Sélection des colonnes intéressantes pour le rapport
colonnes_affichage = ['id', 'username', 'montant_total_paye', 'taux_echec_trans', 'is_fraud']
rapport_lisible = df_rapport[df_rapport['is_fraud'] == 1][colonnes_affichage]

# 6. Affichage
print("Utilisateurs détectés comme fraudeurs :")
display(rapport_lisible)

# 7. Export final
rapport_lisible.to_csv("../features/rapport_fraude_optimise.csv", index=False)
print("Exporté : rapport_fraude_optimise.csv")
# Out:
# Nombre total d'utilisateurs suspects de fraude : 268
# Utilisateurs détectés comme fraudeurs :
#           id     username  montant_total_paye  taux_echec_trans  is_fraud
# 0        1.0       bruyan            3.999999          1.000000         1
# 1        NaN          NaN            0.000000          0.000000         1
# 2        NaN          NaN            0.000000          0.000000         1
# 3        NaN          NaN            0.000000          0.000000         1
# 4        NaN          NaN            0.000000          0.000000         1
# ...      ...          ...                 ...               ...       ...
# 2672  2734.0       Th0m4s            0.000000          0.000000         1
# 2673     NaN          NaN            0.000000          0.000000         1
# 2674  2736.0       UGANDA            0.000000          0.000000         1
# 2675  2737.0      Lomanga            0.000000          0.000000         1
# ...
